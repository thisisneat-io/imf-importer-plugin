# %%
from cognite.neat import NeatSession


# %load_ext autoreload
# %autoreload 2

# %%
neat = NeatSession()
# Out:
# For Neat to improve, we need to collect usage information. You acknowledge and agree that neat may collect usage information.To remove this message run 'neat.opt.in_() or to stop collecting usage information run 'neat.opt.out()'.
# Neat Engine 2.0.5 loaded.

# %%
neat.plugins.data_model.read(name="imf", io = "./imf-example.ttl")
# Out:
# You are using an external plugin IMFDataModelImporterPlugin, which is not developed by the NEAT team.
# Use it at your own risk.
# [WARNING] Experimental feature 'plugin' is subject to change without notice
# [ResourceRetrievalWarning(resources='9ce1c89b-cc58-41b5-a844-aeba2e0bb96a', resource_type='property', error='Unable to determine value type of property'),
#  ResourceRetrievalWarning(resources='207f210e-1073-40d2-bbac-7620e230b9de', resource_type='property', error='Unable to determine value type of property'),
#  ResourceRetrievalWarning(resources='hasAspect', resource_type='property', error='Unable to determine value type of property'),
#  ResourceRetrievalWarning(resources='88d15dc3-3207-4af7-bebc-c9e99f266895', resource_type='property', error='Unable to determine value type of property'),
#  ResourceRetrievalWarning(resources='6419a767-039b-4e57-967c-295a03160a99', resource_type='property', error='Unable to determine value type of property'),
# ...

# %%
neat.read.rdf.
# Out:
# <H2>Data Model</H2><br /><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>level</th>
#       <td>conceptual</td>
#     </tr>
#     <tr>
#       <th>intended for</th>
#       <td>Domain Expert and/or Information Architect</td>
#     </tr>
#     <tr>
#       <th>name</th>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>external_id</th>
#       <td>IMFDataModel</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>v1</td>
#     </tr>
#     <tr>
#       <th>concepts</th>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>properties</th>
#       <td>62</td>
#     </tr>
# ...
